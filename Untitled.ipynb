# %%
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\akriti.pandey\anaconda3\envs\tensorflow\lib\site-packages (2.6.0)
# Requirement already satisfied: tensorboard~=2.6 in c:\users\akriti.pandey\anaconda3\envs\tensorflow\lib\site-packages (from tensorflow) (2.8.0)
# Requirement already satisfied: gast==0.4.0 in c:\users\akriti.pandey\anaconda3\envs\tensorflow\lib\site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: absl-py~=0.10 in c:\users\akriti.pandey\anaconda3\envs\tensorflow\lib\site-packages (from tensorflow) (0.15.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\akriti.pandey\anaconda3\envs\tensorflow\lib\site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: six>=1.15.0 in c:\users\akriti.pandey\anaconda3\envs\tensorflow\lib\site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: keras-preprocessing>=1.1.2 in c:\users\akriti.pandey\anaconda3\envs\tensorflow\lib\site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: keras>=2.4.0 in c:\users\akriti.pandey\anaconda3\envs\tensorflow\lib\site-packages (from tensorflow) (2.8.0)
# Requirement already satisfied: grpcio<2.0,>=1.37.0 in c:\users\akriti.pandey\anaconda3\envs\tensorflow\lib\site-packages (from tensorflow) (1.42.0)
# Requirement already satisfied: protobuf>=3.9.2 in c:\users\akriti.pandey\anaconda3\envs\tensorflow\lib\site-packages (from tensorflow) (3.17.2)
# Requirement already satisfied: wrapt>=1.11.2 in c:\users\akriti.pandey\anaconda3\envs\tensorflow\lib\site-packages (from tensorflow) (1.13.3)
# Requirement already satisfied: tensorflow-estimator~=2.6 in c:\users\akriti.pandey\anaconda3\envs\tensorflow\lib\site-packages (from tensorflow) (2.6.0)
# Requirement already satisfied: clang~=5.0 in c:\users\akriti.pandey\anaconda3\envs\tensorflow\lib\site-packages (from tensorflow) (5.0)
# Requirement already satisfied: wheel>=0.35 in c:\users\akriti.pandey\anaconda3\envs\tensorflow\lib\site-packages (from tensorflow) (0.35.1)
# Requirement already satisfied: typing-extensions>=3.7.4 in c:\users\akriti.pandey\anaconda3\envs\tensorflow\lib\site-packages (from tensorflow) (3.10.0.2)
# Requirement already satisfied: google-pasta~=0.2 in c:\users\akriti.pandey\anaconda3\envs\tensorflow\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: opt-einsum~=3.3.0 in c:\users\akriti.pandey\anaconda3\envs\tensorflow\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: numpy>=1.19 in c:\users\akriti.pandey\anaconda3\envs\tensorflow\lib\site-packages (from tensorflow) (1.21.5)
# Requirement already satisfied: astunparse~=1.6.3 in c:\users\akriti.pandey\anaconda3\envs\tensorflow\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: h5py>=3.1.0 in c:\users\akriti.pandey\anaconda3\envs\tensorflow\lib\site-packages (from tensorflow) (3.6.0)
# Requirement already satisfied: flatbuffers~=1.12 in c:\users\akriti.pandey\anaconda3\envs\tensorflow\lib\site-packages (from tensorflow) (1.12)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\akriti.pandey\anaconda3\envs\tensorflow\lib\site-packages (from tensorboard~=2.6->tensorflow) (1.6.0)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\akriti.pandey\anaconda3\envs\tensorflow\lib\site-packages (from tensorboard~=2.6->tensorflow) (2.27.1)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\akriti.pandey\anaconda3\envs\tensorflow\lib\site-packages (from tensorboard~=2.6->tensorflow) (58.0.4)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\akriti.pandey\anaconda3\envs\tensorflow\lib\site-packages (from tensorboard~=2.6->tensorflow) (0.4.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\akriti.pandey\anaconda3\envs\tensorflow\lib\site-packages (from tensorboard~=2.6->tensorflow) (3.3.4)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\akriti.pandey\anaconda3\envs\tensorflow\lib\site-packages (from tensorboard~=2.6->tensorflow) (0.6.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\akriti.pandey\anaconda3\envs\tensorflow\lib\site-packages (from tensorboard~=2.6->tensorflow) (1.33.0)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\users\akriti.pandey\anaconda3\envs\tensorflow\lib\site-packages (from tensorboard~=2.6->tensorflow) (2.0.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\akriti.pandey\anaconda3\envs\tensorflow\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\akriti.pandey\anaconda3\envs\tensorflow\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow) (4.2.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\akriti.pandey\anaconda3\envs\tensorflow\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow) (4.7.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\akriti.pandey\anaconda3\envs\tensorflow\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow) (1.3.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\akriti.pandey\anaconda3\envs\tensorflow\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (1.26.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\akriti.pandey\anaconda3\envs\tensorflow\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\akriti.pandey\anaconda3\envs\tensorflow\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\akriti.pandey\anaconda3\envs\tensorflow\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (3.3)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\akriti.pandey\anaconda3\envs\tensorflow\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\akriti.pandey\anaconda3\envs\tensorflow\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow) (3.2.0)

# %%
pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in c:\users\akriti.pandey\anaconda3\envs\tensorflow\lib\site-packages (22.0.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install tensorflow-gpu
# Out:
# Requirement already satisfied: tensorflow-gpu in c:\users\akriti.pandey\anaconda3\envs\tensorflow\lib\site-packages (2.8.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\akriti.pandey\anaconda3\envs\tensorflow\lib\site-packages (from tensorflow-gpu) (0.24.0)
# Requirement already satisfied: numpy>=1.20 in c:\users\akriti.pandey\anaconda3\envs\tensorflow\lib\site-packages (from tensorflow-gpu) (1.21.5)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\akriti.pandey\anaconda3\envs\tensorflow\lib\site-packages (from tensorflow-gpu) (0.2.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\akriti.pandey\anaconda3\envs\tensorflow\lib\site-packages (from tensorflow-gpu) (3.10.0.2)
# Requirement already satisfied: keras<2.9,>=2.8.0rc0 in c:\users\akriti.pandey\anaconda3\envs\tensorflow\lib\site-packages (from tensorflow-gpu) (2.8.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\akriti.pandey\anaconda3\envs\tensorflow\lib\site-packages (from tensorflow-gpu) (1.1.0)
# Requirement already satisfied: tensorboard<2.9,>=2.8 in c:\users\akriti.pandey\anaconda3\envs\tensorflow\lib\site-packages (from tensorflow-gpu) (2.8.0)
# Requirement already satisfied: tf-estimator-nightly==2.8.0.dev2021122109 in c:\users\akriti.pandey\anaconda3\envs\tensorflow\lib\site-packages (from tensorflow-gpu) (2.8.0.dev2021122109)
# Requirement already satisfied: six>=1.12.0 in c:\users\akriti.pandey\anaconda3\envs\tensorflow\lib\site-packages (from tensorflow-gpu) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\akriti.pandey\anaconda3\envs\tensorflow\lib\site-packages (from tensorflow-gpu) (1.42.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\akriti.pandey\anaconda3\envs\tensorflow\lib\site-packages (from tensorflow-gpu) (1.1.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\akriti.pandey\anaconda3\envs\tensorflow\lib\site-packages (from tensorflow-gpu) (3.3.0)
# Requirement already satisfied: protobuf>=3.9.2 in c:\users\akriti.pandey\anaconda3\envs\tensorflow\lib\site-packages (from tensorflow-gpu) (3.17.2)
# Requirement already satisfied: absl-py>=0.4.0 in c:\users\akriti.pandey\anaconda3\envs\tensorflow\lib\site-packages (from tensorflow-gpu) (0.15.0)
# Requirement already satisfied: gast>=0.2.1 in c:\users\akriti.pandey\anaconda3\envs\tensorflow\lib\site-packages (from tensorflow-gpu) (0.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\akriti.pandey\anaconda3\envs\tensorflow\lib\site-packages (from tensorflow-gpu) (1.6.3)
# Requirement already satisfied: setuptools in c:\users\akriti.pandey\anaconda3\envs\tensorflow\lib\site-packages (from tensorflow-gpu) (58.0.4)
# Requirement already satisfied: flatbuffers>=1.12 in c:\users\akriti.pandey\anaconda3\envs\tensorflow\lib\site-packages (from tensorflow-gpu) (1.12)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\akriti.pandey\anaconda3\envs\tensorflow\lib\site-packages (from tensorflow-gpu) (1.13.3)
# Requirement already satisfied: libclang>=9.0.1 in c:\users\akriti.pandey\anaconda3\envs\tensorflow\lib\site-packages (from tensorflow-gpu) (13.0.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\akriti.pandey\anaconda3\envs\tensorflow\lib\site-packages (from tensorflow-gpu) (3.6.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\akriti.pandey\anaconda3\envs\tensorflow\lib\site-packages (from astunparse>=1.6.0->tensorflow-gpu) (0.35.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\akriti.pandey\anaconda3\envs\tensorflow\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow-gpu) (2.27.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\akriti.pandey\anaconda3\envs\tensorflow\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow-gpu) (1.6.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\akriti.pandey\anaconda3\envs\tensorflow\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow-gpu) (1.33.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\akriti.pandey\anaconda3\envs\tensorflow\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow-gpu) (0.4.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\akriti.pandey\anaconda3\envs\tensorflow\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow-gpu) (0.6.0)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\users\akriti.pandey\anaconda3\envs\tensorflow\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow-gpu) (2.0.3)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\akriti.pandey\anaconda3\envs\tensorflow\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow-gpu) (3.3.4)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\akriti.pandey\anaconda3\envs\tensorflow\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow-gpu) (4.2.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\akriti.pandey\anaconda3\envs\tensorflow\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow-gpu) (4.7.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\akriti.pandey\anaconda3\envs\tensorflow\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow-gpu) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\akriti.pandey\anaconda3\envs\tensorflow\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow-gpu) (1.3.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\akriti.pandey\anaconda3\envs\tensorflow\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow-gpu) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\akriti.pandey\anaconda3\envs\tensorflow\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow-gpu) (1.26.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\akriti.pandey\anaconda3\envs\tensorflow\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow-gpu) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\akriti.pandey\anaconda3\envs\tensorflow\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow-gpu) (2.0.4)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\akriti.pandey\anaconda3\envs\tensorflow\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow-gpu) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\akriti.pandey\anaconda3\envs\tensorflow\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow-gpu) (3.2.0)

# %%
import tensorflow as tf
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\AKRITI~1.PAN\AppData\Local\Temp/ipykernel_6476/3793406994.py in <module>
# ----> 1 import tensorflow as tf
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\__init__.py in <module>
#     471 if hasattr(_current_module, "keras"):
#     472   try:
# --> 473     keras._load()
#     474   except ImportError:
#     475     pass
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\util\lazy_loader.py in _load(self)
#      39     """Load the module and insert it into the parent's globals."""
#      40     # Import the target module and insert it into the parent's namespace
# ---> 41     module = importlib.import_module(self.__name__)
#      42     self._parent_module_globals[self._local_name] = module
#      43
#
# ~\Anaconda3\envs\tensorflow\lib\importlib\__init__.py in import_module(name, package)
#     125                 break
#     126             level += 1
# --> 127     return _bootstrap._gcd_import(name[level:], package, level)
#     128
#     129
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\keras\__init__.py in <module>
#      23
#      24 # See b/110718070#comment18 for more details about this import.
# ---> 25 from keras import models
#      26
#      27 from keras.engine.input_layer import Input
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\keras\models.py in <module>
#      18 import tensorflow.compat.v2 as tf
#      19 from keras import backend
# ---> 20 from keras import metrics as metrics_module
#      21 from keras import optimizer_v1
#      22 from keras.engine import functional
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\keras\metrics.py in <module>
#      24
#      25 import numpy as np
# ---> 26 from keras import activations
#      27 from keras import backend
#      28 from keras.engine import base_layer
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\keras\activations.py in <module>
#      18
#      19 from keras import backend
# ---> 20 from keras.layers import advanced_activations
#      21 from keras.utils.generic_utils import deserialize_keras_object
#      22 from keras.utils.generic_utils import serialize_keras_object
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\keras\layers\__init__.py in <module>
#      29
#      30 # Image preprocessing layers.
# ---> 31 from keras.layers.preprocessing.image_preprocessing import CenterCrop
#      32 from keras.layers.preprocessing.image_preprocessing import RandomCrop
#      33 from keras.layers.preprocessing.image_preprocessing import RandomFlip
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\keras\layers\preprocessing\image_preprocessing.py in <module>
#      22 from keras.engine import base_layer
#      23 from keras.engine import base_preprocessing_layer
# ---> 24 from keras.preprocessing import image as image_preprocessing
#      25 from keras.utils import control_flow_util
#      26 from tensorflow.python.ops import stateless_random_ops
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\keras\preprocessing\__init__.py in <module>
#      24 from keras.preprocessing import text
#      25 from keras.preprocessing import timeseries
# ---> 26 from keras.utils import all_utils as utils
#      27
#      28 # This exists for compatibility with prior version of keras_preprocessing.
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\keras\utils\all_utils.py in <module>
#      32 from keras.utils.generic_utils import serialize_keras_object
#      33 from keras.utils.layer_utils import get_source_inputs
# ---> 34 from keras.utils.multi_gpu_utils import multi_gpu_model
#      35 from keras.utils.np_utils import normalize
#      36 from keras.utils.np_utils import to_categorical
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\keras\utils\multi_gpu_utils.py in <module>
#      18 from keras import backend
#      19 from keras.engine.training import Model
# ---> 20 from keras.layers.core import Lambda
#      21 from keras.layers.merge import concatenate
#      22
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\keras\layers\core\__init__.py in <module>
#      18 from keras.layers.core.activity_regularization import ActivityRegularization
#      19 from keras.layers.core.dense import Dense
# ---> 20 from keras.layers.core.dropout import Dropout
#      21 from keras.layers.core.flatten import Flatten
#      22 from keras.layers.core.lambda_layer import Lambda
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\keras\layers\core\dropout.py in <module>
#      24
#      25 @keras_export('keras.layers.Dropout')
# ---> 26 class Dropout(base_layer.BaseRandomLayer):
#      27   """Applies Dropout to the input.
#      28
#
# AttributeError: module 'keras.engine.base_layer' has no attribute 'BaseRandomLayer'

# %%
from tensorflow import keras
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\AKRITI~1.PAN\AppData\Local\Temp/ipykernel_6476/1589520110.py in <module>
# ----> 1 from tensorflow import keras
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\__init__.py in <module>
#     471 if hasattr(_current_module, "keras"):
#     472   try:
# --> 473     keras._load()
#     474   except ImportError:
#     475     pass
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\util\lazy_loader.py in _load(self)
#      39     """Load the module and insert it into the parent's globals."""
#      40     # Import the target module and insert it into the parent's namespace
# ---> 41     module = importlib.import_module(self.__name__)
#      42     self._parent_module_globals[self._local_name] = module
#      43
#
# ~\Anaconda3\envs\tensorflow\lib\importlib\__init__.py in import_module(name, package)
#     125                 break
#     126             level += 1
# --> 127     return _bootstrap._gcd_import(name[level:], package, level)
#     128
#     129
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\keras\__init__.py in <module>
#      23
#      24 # See b/110718070#comment18 for more details about this import.
# ---> 25 from keras import models
#      26
#      27 from keras.engine.input_layer import Input
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\keras\models.py in <module>
#      18 import tensorflow.compat.v2 as tf
#      19 from keras import backend
# ---> 20 from keras import metrics as metrics_module
#      21 from keras import optimizer_v1
#      22 from keras.engine import functional
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\keras\metrics.py in <module>
#      24
#      25 import numpy as np
# ---> 26 from keras import activations
#      27 from keras import backend
#      28 from keras.engine import base_layer
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\keras\activations.py in <module>
#      18
#      19 from keras import backend
# ---> 20 from keras.layers import advanced_activations
#      21 from keras.utils.generic_utils import deserialize_keras_object
#      22 from keras.utils.generic_utils import serialize_keras_object
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\keras\layers\__init__.py in <module>
#      29
#      30 # Image preprocessing layers.
# ---> 31 from keras.layers.preprocessing.image_preprocessing import CenterCrop
#      32 from keras.layers.preprocessing.image_preprocessing import RandomCrop
#      33 from keras.layers.preprocessing.image_preprocessing import RandomFlip
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\keras\layers\preprocessing\image_preprocessing.py in <module>
#      22 from keras.engine import base_layer
#      23 from keras.engine import base_preprocessing_layer
# ---> 24 from keras.preprocessing import image as image_preprocessing
#      25 from keras.utils import control_flow_util
#      26 from tensorflow.python.ops import stateless_random_ops
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\keras\preprocessing\__init__.py in <module>
#      24 from keras.preprocessing import text
#      25 from keras.preprocessing import timeseries
# ---> 26 from keras.utils import all_utils as utils
#      27
#      28 # This exists for compatibility with prior version of keras_preprocessing.
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\keras\utils\all_utils.py in <module>
#      32 from keras.utils.generic_utils import serialize_keras_object
#      33 from keras.utils.layer_utils import get_source_inputs
# ---> 34 from keras.utils.multi_gpu_utils import multi_gpu_model
#      35 from keras.utils.np_utils import normalize
#      36 from keras.utils.np_utils import to_categorical
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\keras\utils\multi_gpu_utils.py in <module>
#      18 from keras import backend
#      19 from keras.engine.training import Model
# ---> 20 from keras.layers.core import Lambda
#      21 from keras.layers.merge import concatenate
#      22
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\keras\layers\core\__init__.py in <module>
#      18 from keras.layers.core.activity_regularization import ActivityRegularization
#      19 from keras.layers.core.dense import Dense
# ---> 20 from keras.layers.core.dropout import Dropout
#      21 from keras.layers.core.flatten import Flatten
#      22 from keras.layers.core.lambda_layer import Lambda
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\keras\layers\core\dropout.py in <module>
#      24
#      25 @keras_export('keras.layers.Dropout')
# ---> 26 class Dropout(base_layer.BaseRandomLayer):
#      27   """Applies Dropout to the input.
#      28
#
# AttributeError: module 'keras.engine.base_layer' has no attribute 'BaseRandomLayer'

# %%
# !pip install opencv-python matplotlib
# Out:
# Requirement already satisfied: opencv-python in c:\users\akriti.pandey\anaconda3\envs\tensorflow\lib\site-packages (4.5.5.62)
# Requirement already satisfied: matplotlib in c:\users\akriti.pandey\anaconda3\envs\tensorflow\lib\site-packages (3.5.1)
# Requirement already satisfied: numpy>=1.19.3 in c:\users\akriti.pandey\anaconda3\envs\tensorflow\lib\site-packages (from opencv-python) (1.21.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\akriti.pandey\anaconda3\envs\tensorflow\lib\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\akriti.pandey\anaconda3\envs\tensorflow\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\akriti.pandey\anaconda3\envs\tensorflow\lib\site-packages (from matplotlib) (4.29.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\akriti.pandey\anaconda3\envs\tensorflow\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\akriti.pandey\anaconda3\envs\tensorflow\lib\site-packages (from matplotlib) (3.0.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\akriti.pandey\anaconda3\envs\tensorflow\lib\site-packages (from matplotlib) (9.0.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\akriti.pandey\anaconda3\envs\tensorflow\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: six>=1.5 in c:\users\akriti.pandey\anaconda3\envs\tensorflow\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import cv2
import os
import random
import numpy as np
from matplotlib import pyplot as plt

# %%
from keras import models
import keras.engine.topology as KE
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\AKRITI~1.PAN\AppData\Local\Temp/ipykernel_6476/517934962.py in <module>
# ----> 1 from keras import models
#       2 import keras.engine.topology as KE
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\keras\__init__.py in <module>
#      23
#      24 # See b/110718070#comment18 for more details about this import.
# ---> 25 from keras import models
#      26
#      27 from keras.engine.input_layer import Input
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\keras\models.py in <module>
#      18 import tensorflow.compat.v2 as tf
#      19 from keras import backend
# ---> 20 from keras import metrics as metrics_module
#      21 from keras import optimizer_v1
#      22 from keras.engine import functional
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\keras\metrics.py in <module>
#      24
#      25 import numpy as np
# ---> 26 from keras import activations
#      27 from keras import backend
#      28 from keras.engine import base_layer
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\keras\activations.py in <module>
#      18
#      19 from keras import backend
# ---> 20 from keras.layers import advanced_activations
#      21 from keras.utils.generic_utils import deserialize_keras_object
#      22 from keras.utils.generic_utils import serialize_keras_object
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\keras\layers\__init__.py in <module>
#      29
#      30 # Image preprocessing layers.
# ---> 31 from keras.layers.preprocessing.image_preprocessing import CenterCrop
#      32 from keras.layers.preprocessing.image_preprocessing import RandomCrop
#      33 from keras.layers.preprocessing.image_preprocessing import RandomFlip
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\keras\layers\preprocessing\image_preprocessing.py in <module>
#      22 from keras.engine import base_layer
#      23 from keras.engine import base_preprocessing_layer
# ---> 24 from keras.preprocessing import image as image_preprocessing
#      25 from keras.utils import control_flow_util
#      26 from tensorflow.python.ops import stateless_random_ops
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\keras\preprocessing\__init__.py in <module>
#      24 from keras.preprocessing import text
#      25 from keras.preprocessing import timeseries
# ---> 26 from keras.utils import all_utils as utils
#      27
#      28 # This exists for compatibility with prior version of keras_preprocessing.
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\keras\utils\all_utils.py in <module>
#      32 from keras.utils.generic_utils import serialize_keras_object
#      33 from keras.utils.layer_utils import get_source_inputs
# ---> 34 from keras.utils.multi_gpu_utils import multi_gpu_model
#      35 from keras.utils.np_utils import normalize
#      36 from keras.utils.np_utils import to_categorical
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\keras\utils\multi_gpu_utils.py in <module>
#      18 from keras import backend
#      19 from keras.engine.training import Model
# ---> 20 from keras.layers.core import Lambda
#      21 from keras.layers.merge import concatenate
#      22
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\keras\layers\core\__init__.py in <module>
#      18 from keras.layers.core.activity_regularization import ActivityRegularization
#      19 from keras.layers.core.dense import Dense
# ---> 20 from keras.layers.core.dropout import Dropout
#      21 from keras.layers.core.flatten import Flatten
#      22 from keras.layers.core.lambda_layer import Lambda
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\keras\layers\core\dropout.py in <module>
#      24
#      25 @keras_export('keras.layers.Dropout')
# ---> 26 class Dropout(base_layer.BaseRandomLayer):
#      27   """Applies Dropout to the input.
#      28
#
# AttributeError: module 'keras.engine.base_layer' has no attribute 'BaseRandomLayer'

# %%
#import keras.engine.topology as KE

# %%
#from keras import __version__
from keras.api.v2.keras import __internal__
from keras.api.v2.keras import activation
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\AKRITI~1.PAN\AppData\Local\Temp/ipykernel_6476/2915694905.py in <module>
#       1 #from keras import __version__
# ----> 2 from keras.api.v2.keras import __internal__
#       3 from keras.api.v2.keras import activation
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\keras\__init__.py in <module>
#      23
#      24 # See b/110718070#comment18 for more details about this import.
# ---> 25 from keras import models
#      26
#      27 from keras.engine.input_layer import Input
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\keras\models.py in <module>
#      18 import tensorflow.compat.v2 as tf
#      19 from keras import backend
# ---> 20 from keras import metrics as metrics_module
#      21 from keras import optimizer_v1
#      22 from keras.engine import functional
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\keras\metrics.py in <module>
#      24
#      25 import numpy as np
# ---> 26 from keras import activations
#      27 from keras import backend
#      28 from keras.engine import base_layer
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\keras\activations.py in <module>
#      18
#      19 from keras import backend
# ---> 20 from keras.layers import advanced_activations
#      21 from keras.utils.generic_utils import deserialize_keras_object
#      22 from keras.utils.generic_utils import serialize_keras_object
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\keras\layers\__init__.py in <module>
#      29
#      30 # Image preprocessing layers.
# ---> 31 from keras.layers.preprocessing.image_preprocessing import CenterCrop
#      32 from keras.layers.preprocessing.image_preprocessing import RandomCrop
#      33 from keras.layers.preprocessing.image_preprocessing import RandomFlip
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\keras\layers\preprocessing\image_preprocessing.py in <module>
#      22 from keras.engine import base_layer
#      23 from keras.engine import base_preprocessing_layer
# ---> 24 from keras.preprocessing import image as image_preprocessing
#      25 from keras.utils import control_flow_util
#      26 from tensorflow.python.ops import stateless_random_ops
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\keras\preprocessing\__init__.py in <module>
#      24 from keras.preprocessing import text
#      25 from keras.preprocessing import timeseries
# ---> 26 from keras.utils import all_utils as utils
#      27
#      28 # This exists for compatibility with prior version of keras_preprocessing.
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\keras\utils\all_utils.py in <module>
#      32 from keras.utils.generic_utils import serialize_keras_object
#      33 from keras.utils.layer_utils import get_source_inputs
# ---> 34 from keras.utils.multi_gpu_utils import multi_gpu_model
#      35 from keras.utils.np_utils import normalize
#      36 from keras.utils.np_utils import to_categorical
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\keras\utils\multi_gpu_utils.py in <module>
#      18 from keras import backend
#      19 from keras.engine.training import Model
# ---> 20 from keras.layers.core import Lambda
#      21 from keras.layers.merge import concatenate
#      22
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\keras\layers\core\__init__.py in <module>
#      18 from keras.layers.core.activity_regularization import ActivityRegularization
#      19 from keras.layers.core.dense import Dense
# ---> 20 from keras.layers.core.dropout import Dropout
#      21 from keras.layers.core.flatten import Flatten
#      22 from keras.layers.core.lambda_layer import Lambda
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\keras\layers\core\dropout.py in <module>
#      24
#      25 @keras_export('keras.layers.Dropout')
# ---> 26 class Dropout(base_layer.BaseRandomLayer):
#      27   """Applies Dropout to the input.
#      28
#
# AttributeError: module 'keras.engine.base_layer' has no attribute 'BaseRandomLayer'

# %%
pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in c:\users\akriti.pandey\anaconda3\envs\tensorflow\lib\site-packages (22.0.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Layer, Conv2D, Dense, MaxPooling2D, Input, Flatten
import tensorflow as tf
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\AKRITI~1.PAN\AppData\Local\Temp/ipykernel_6476/1653996397.py in <module>
# ----> 1 from tensorflow.keras.models import Model
#       2 from tensorflow.keras.layers import Layer, Conv2D, Dense, MaxPooling2D, Input, Flatten
#       3 import tensorflow as tf
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\keras\api\_v2\keras\__init__.py in <module>
#       8 import sys as _sys
#       9
# ---> 10 from keras import __version__
#      11 from keras.api._v2.keras import __internal__
#      12 from keras.api._v2.keras import activations
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\keras\__init__.py in <module>
#      23
#      24 # See b/110718070#comment18 for more details about this import.
# ---> 25 from keras import models
#      26
#      27 from keras.engine.input_layer import Input
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\keras\models.py in <module>
#      18 import tensorflow.compat.v2 as tf
#      19 from keras import backend
# ---> 20 from keras import metrics as metrics_module
#      21 from keras import optimizer_v1
#      22 from keras.engine import functional
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\keras\metrics.py in <module>
#      24
#      25 import numpy as np
# ---> 26 from keras import activations
#      27 from keras import backend
#      28 from keras.engine import base_layer
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\keras\activations.py in <module>
#      18
#      19 from keras import backend
# ---> 20 from keras.layers import advanced_activations
#      21 from keras.utils.generic_utils import deserialize_keras_object
#      22 from keras.utils.generic_utils import serialize_keras_object
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\keras\layers\__init__.py in <module>
#      29
#      30 # Image preprocessing layers.
# ---> 31 from keras.layers.preprocessing.image_preprocessing import CenterCrop
#      32 from keras.layers.preprocessing.image_preprocessing import RandomCrop
#      33 from keras.layers.preprocessing.image_preprocessing import RandomFlip
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\keras\layers\preprocessing\image_preprocessing.py in <module>
#      22 from keras.engine import base_layer
#      23 from keras.engine import base_preprocessing_layer
# ---> 24 from keras.preprocessing import image as image_preprocessing
#      25 from keras.utils import control_flow_util
#      26 from tensorflow.python.ops import stateless_random_ops
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\keras\preprocessing\__init__.py in <module>
#      24 from keras.preprocessing import text
#      25 from keras.preprocessing import timeseries
# ---> 26 from keras.utils import all_utils as utils
#      27
#      28 # This exists for compatibility with prior version of keras_preprocessing.
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\keras\utils\all_utils.py in <module>
#      32 from keras.utils.generic_utils import serialize_keras_object
#      33 from keras.utils.layer_utils import get_source_inputs
# ---> 34 from keras.utils.multi_gpu_utils import multi_gpu_model
#      35 from keras.utils.np_utils import normalize
#      36 from keras.utils.np_utils import to_categorical
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\keras\utils\multi_gpu_utils.py in <module>
#      18 from keras import backend
#      19 from keras.engine.training import Model
# ---> 20 from keras.layers.core import Lambda
#      21 from keras.layers.merge import concatenate
#      22
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\keras\layers\core\__init__.py in <module>
#      18 from keras.layers.core.activity_regularization import ActivityRegularization
#      19 from keras.layers.core.dense import Dense
# ---> 20 from keras.layers.core.dropout import Dropout
#      21 from keras.layers.core.flatten import Flatten
#      22 from keras.layers.core.lambda_layer import Lambda
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\keras\layers\core\dropout.py in <module>
#      24
#      25 @keras_export('keras.layers.Dropout')
# ---> 26 class Dropout(base_layer.BaseRandomLayer):
#      27   """Applies Dropout to the input.
#      28
#
# AttributeError: module 'keras.engine.base_layer' has no attribute 'BaseRandomLayer'

# %% [markdown]
# # SET GPU

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus: 
    tf.config.experimental.set_memory_growth(gpu, True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\AKRITI~1.PAN\AppData\Local\Temp/ipykernel_6476/1307068638.py in <module>
# ----> 1 gpus = tf.config.experimental.list_physical_devices('GPU')
#       2 for gpu in gpus:
#       3     tf.config.experimental.set_memory_growth(gpu, True)
#
# NameError: name 'tf' is not defined

# %%
POS_PATH = os.path.join('data', 'positive')
NEG_PATH = os.path.join('data', 'negative')
ANC_PATH = os.path.join('data', 'anchor')

# %%
os.makedirs(POS_PATH)
os.makedirs(NEG_PATH)
os.makedirs(ANC_PATH)
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# C:\Users\AKRITI~1.PAN\AppData\Local\Temp/ipykernel_6476/1007565961.py in <module>
# ----> 1 os.makedirs(POS_PATH)
#       2 os.makedirs(NEG_PATH)
#       3 os.makedirs(ANC_PATH)
#
# ~\Anaconda3\envs\tensorflow\lib\os.py in makedirs(name, mode, exist_ok)
#     223             return
#     224     try:
# --> 225         mkdir(name, mode)
#     226     except OSError:
#     227         # Cannot rely on checking for EEXIST, since the operating system
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'data\\positive'
